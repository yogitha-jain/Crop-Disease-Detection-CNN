# %%
import numpy as np
import pandas as pd
data=pd.read_csv(r"C:\Users\Lenovo\Desktop\CattleClean\cattle_train.csv")

# %%
hypo=['%']*4
positive_exp=data[data.iloc[:,-1]=='YES']
print(positive_exp)

# %%
hypo=positive_exp.iloc[0,:-1].tolist()
print(hypo)

# %%
for i in range (1,len(positive_exp)):
    print("it",i)
    print("current",hypo)
    for j in range(len(hypo)):
        if hypo[j]!=positive_exp.iloc[i,j]:
            hypo[j]='?'
    print("up",hypo)
print("maximally")
print(hypo)
